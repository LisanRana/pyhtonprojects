# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.colors as mcolors

# %%
#read file
data = pd.read_csv("heart_data.csv")
data
# Out:
#      rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  \
# 0        106           3            0   67           0     142
# 1        120           2            0   50           0     158
# 2        126           3            2   35           0     156
# 3        150           3            2   63           0     154
# 4        140           3            2   46           0     120
# ..       ...         ...          ...  ...         ...     ...
# 292      130           2            2   62           0      97
# 293      100           3            0   58           0     122
# 294      138           3            0   59           0     182
# 295      130           3            2   56           1     103
# 296      150           3            2   50           0     128
#
#      exercise_angina  gender  st_slope  cholesterol  st_depression  rest_ecg  \
# 0                  0       0         0          223            0.3         0
# ...

# %%
print(data.head())
# Out:
#    rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  exercise_angina  \
# 0      106           3            0   67           0     142                0
# 1      120           2            0   50           0     158                0
# 2      126           3            2   35           0     156                1
# 3      150           3            2   63           0     154                0
# 4      140           3            2   46           0     120                1
#
#    gender  st_slope  cholesterol  st_depression  rest_ecg  num_vessels  \
# 0       0         0          223            0.3         0            2
# 1       0         1          219            1.6         0            0
# 2       1         0          282            0.0         2            0
# 3       0         1          407            4.0         2            3
# 4       1         1          311            1.8         0            2
#
#    diagnosis
# 0          0
# 1          0
# 2          1
# ...

# %%
plt.hist(data['chest_pain'],bins=4,range=(1,3))
plt.title('chest_pain')
# Out:
# Text(0.5, 1.0, 'chest_pain')

# %%
plt.hist(data['age'],bins=9,range=(20,80))
plt.title('age')
# Out:
# Text(0.5, 1.0, 'age')

# %%
plt.scatter(data['chest_pain'],data['age'])
plt.xlabel('chest_pain')
plt.ylabel('age')
# Out:
# Text(0, 0.5, 'age')

# %%
#grouping the mean
data.groupby(['age']).mean()
# Out:
#         rest_bp  chest_pain  thalassemia  fasting_bs      max_hr  \
# age
# 29   130.000000    1.000000     0.000000    0.000000  202.000000
# 34   118.000000    0.500000     0.000000    0.000000  183.000000
# 35   126.500000    2.500000     1.000000    0.000000  160.500000
# 37   125.000000    2.000000     0.000000    0.000000  178.500000
# 38   120.000000    0.000000     2.000000    0.000000  182.000000
# 39   122.500000    2.250000     0.500000    0.000000  163.250000
# 40   134.000000    2.000000     2.000000    0.000000  157.666667
# 41   119.000000    1.500000     0.300000    0.000000  164.700000
# 42   127.000000    2.000000     0.375000    0.125000  160.250000
# 43   125.571429    2.714286     0.857143    0.142857  156.571429
# 44   120.727273    2.000000     0.272727    0.000000  168.818182
# 45   122.375000    1.875000     0.500000    0.000000  155.875000
# 46   128.000000    2.142857     0.857143    0.142857  150.142857
# ...

# %%
data.groupby(['age','cholesterol']).mean()
# Out:
#                  rest_bp  chest_pain  thalassemia  fasting_bs  max_hr  \
# age cholesterol
# 29  204            130.0         1.0          0.0         0.0   202.0
# 34  182            118.0         0.0          0.0         0.0   174.0
#     210            118.0         1.0          0.0         0.0   192.0
# 35  183            138.0         3.0          0.0         0.0   182.0
#     192            122.0         1.0          0.0         0.0   174.0
# ...                  ...         ...          ...         ...     ...
# 71  265            110.0         2.0          0.0         1.0   130.0
#     302            160.0         1.0          0.0         0.0   162.0
# 74  269            120.0         1.0          0.0         0.0   121.0
# 76  197            140.0         2.0          0.0         0.0   116.0
# 77  304            125.0         3.0          0.0         0.0   162.0
#
#                  exercise_angina  gender  st_slope  st_depression  rest_ecg  \
# age cholesterol
# ...

# %%
#drop column
data.drop(['age','cholesterol','gender'],axis=1).head()
# Out:
#    rest_bp  chest_pain  thalassemia  fasting_bs  max_hr  exercise_angina  \
# 0      106           3            0           0     142                0
# 1      120           2            0           0     158                0
# 2      126           3            2           0     156                1
# 3      150           3            2           0     154                0
# 4      140           3            2           0     120                1
#
#    st_slope  st_depression  rest_ecg  num_vessels  diagnosis
# 0         0            0.3         0            2          0
# 1         1            1.6         0            0          0
# 2         0            0.0         2            0          1
# 3         1            4.0         2            3          1
# 4         1            1.8         0            2          1

# %%
#drop rows
data.drop(([1,2,3]),axis=0).head()
# Out:
#    rest_bp  chest_pain  thalassemia  age  fasting_bs  max_hr  exercise_angina  \
# 0      106           3            0   67           0     142                0
# 4      140           3            2   46           0     120                1
# 5      110           3            1   57           0     126                1
# 6      130           1            0   49           0     171                0
# 7      136           2            0   52           0     169                0
#
#    gender  st_slope  cholesterol  st_depression  rest_ecg  num_vessels  \
# 0       0         0          223            0.3         0            2
# 4       1         1          311            1.8         0            2
# 5       1         1          201            1.5         0            0
# 6       1         0          266            0.6         0            0
# 7       0         1          196            0.1         2            0
#
#    diagnosis
# 0          0
# 4          1
# 5          0
# ...

# %%
#plot bar of single column
pd.value_counts(data['chest_pain']).plot.bar()
# Out:
# <Axes: xlabel='chest_pain'>

# %%
data.describe()
# Out:
#           rest_bp  chest_pain  thalassemia         age  fasting_bs  \
# count  297.000000  297.000000   297.000000  297.000000  297.000000
# mean   131.693603    2.158249     0.835017   54.542088    0.144781
# std     17.762806    0.964859     0.956690    9.049736    0.352474
# min     94.000000    0.000000     0.000000   29.000000    0.000000
# 25%    120.000000    2.000000     0.000000   48.000000    0.000000
# 50%    130.000000    2.000000     0.000000   56.000000    0.000000
# 75%    140.000000    3.000000     2.000000   61.000000    0.000000
# max    200.000000    3.000000     2.000000   77.000000    1.000000
#
#            max_hr  exercise_angina      gender    st_slope  cholesterol  \
# count  297.000000       297.000000  297.000000  297.000000   297.000000
# mean   149.599327         0.326599    0.676768    0.602694   247.350168
# std     22.941562         0.469761    0.468500    0.618187    51.997583
# min     71.000000         0.000000    0.000000    0.000000   126.000000
# ...

# %%
data.isnull()
# Out:
#      rest_bp  chest_pain  thalassemia    age  fasting_bs  max_hr  \
# 0      False       False        False  False       False   False
# 1      False       False        False  False       False   False
# 2      False       False        False  False       False   False
# 3      False       False        False  False       False   False
# 4      False       False        False  False       False   False
# ..       ...         ...          ...    ...         ...     ...
# 292    False       False        False  False       False   False
# 293    False       False        False  False       False   False
# 294    False       False        False  False       False   False
# 295    False       False        False  False       False   False
# 296    False       False        False  False       False   False
#
#      exercise_angina  gender  st_slope  cholesterol  st_depression  rest_ecg  \
# 0              False   False     False        False          False     False
# ...

# %%
data.isnull().sum()
# Out:
# rest_bp            0
# chest_pain         0
# thalassemia        0
# age                0
# fasting_bs         0
# max_hr             0
# exercise_angina    0
# gender             0
# st_slope           0
# cholesterol        0
# st_depression      0
# rest_ecg           0
# num_vessels        0
# diagnosis          0
# dtype: int64

# %%
#criteria is defined
data[data['age']<30].groupby(['chest_pain']).mean()
# Out:
#             rest_bp  thalassemia   age  fasting_bs  max_hr  exercise_angina  \
# chest_pain
# 1             130.0          0.0  29.0         0.0   202.0              0.0
#
#             gender  st_slope  cholesterol  st_depression  rest_ecg  \
# chest_pain
# 1              1.0       0.0        204.0            0.0       2.0
#
#             num_vessels  diagnosis
# chest_pain
# 1                   0.0        0.0

# %%
data[data['age']<40].groupby(['chest_pain','cholesterol']).mean()
# Out:
#                         rest_bp  thalassemia   age  fasting_bs  max_hr  \
# chest_pain cholesterol
# 0          182            118.0          0.0  34.0         0.0   174.0
#            231            120.0          2.0  38.0         0.0   182.0
# 1          192            122.0          0.0  35.0         0.0   174.0
#            204            130.0          0.0  29.0         0.0   202.0
#            210            118.0          0.0  34.0         0.0   192.0
# 2          199             94.0          0.0  39.0         0.0   179.0
#            215            120.0          0.0  37.0         0.0   170.0
#            220            138.0          0.0  39.0         0.0   152.0
#            250            130.0          0.0  37.0         0.0   187.0
#            321            140.0          0.0  39.0         0.0   182.0
# 3          183            138.0          0.0  35.0         0.0   182.0
#            198            120.0          2.0  35.0         0.0   130.0
# ...

# %%
#plot histogram

plt.hist(data['rest_bp'],bins=9,range=(80,160))
plt.title('rest_bp')
# Out:
# Text(0.5, 1.0, 'rest_bp')

# %%
data.iloc[1,2,3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.iloc([1,2,3])
#
# NameError: name 'data' is not defined
